# %% [markdown]
# # Task 02: Stock price prediction using LSTM
# This task involves analysing stock prices for a company (in this case [microsoft](https://www.microsoft.com/en-us/)) and predict upcoming stock prices...

# %% [markdown]
# # Data analysis:
#
# The dataset was downloaded from [Kaggle](https://www.kaggle.com/datasets/mayankanand2701/microsoft-stock-price-dataset).
#
# ## Dataset structure:
# - **Date**: The date.
# - **Open**: The opening price of the stock.
# - **High**: The high price of that day.
# - **Low**: The low price of that day.
# - **Close**: The closed price of that day.
# - **Volume**: The amount of stocks traded during that day.
# - **Adj\[usted] Close**: The stock's closing price that has been amended to include any distributions/corporate actions that occurs before next days open.

# %% [markdown]
# ## Loading data:

# %%
# !ls
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# since we already know that there is a column containing a date, we can directly convert it to datetime
df = pd.read_csv("./Dataset/Microsoft Dataset.csv", parse_dates=["Date"]) # the name was not changed so that once the data is downloaded from its source it comes in the exact file name
df.head()
# Out:
# Dataset  Stock_price_prediction.ipynb  Untitled.ipynb
#         Date      Open      High       Low     Close  Adj Close      Volume
# 0 1986-03-13  0.088542  0.101563  0.088542  0.097222   0.060055  1031788800
# 1 1986-03-14  0.097222  0.102431  0.097222  0.100694   0.062199   308160000
# 2 1986-03-17  0.100694  0.103299  0.100694  0.102431   0.063272   133171200
# 3 1986-03-18  0.102431  0.103299  0.098958  0.099826   0.061663    67766400
# 4 1986-03-19  0.099826  0.100694  0.097222  0.098090   0.060591    47894400

# %%
df.sort_values("Date")
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060055
# 1    1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062199
# 2    1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063272
# 3    1986-03-18    0.102431    0.103299    0.098958    0.099826    0.061663
# 4    1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060591
# ...         ...         ...         ...         ...         ...         ...
# 9627 2024-05-24  427.190002  431.059998  424.410004  430.160004  430.160004
# 9628 2024-05-28  429.630005  430.820007  426.600006  430.320007  430.320007
# 9629 2024-05-29  425.690002  430.940002  425.690002  429.170013  429.170013
# 9630 2024-05-30  424.299988  424.299988  414.239990  414.670013  414.670013
# 9631 2024-05-31  416.410004  416.630005  404.519989  406.760010  406.760010
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9627    11845800
# 9628    15718000
# 9629    15517100
# 9630    28394500
# 9631    17190518
#
# [9632 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9632 entries, 0 to 9631
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       9632 non-null   datetime64[ns]
#  1   Open       9632 non-null   float64
#  2   High       9632 non-null   float64
#  3   Low        9632 non-null   float64
#  4   Close      9632 non-null   float64
#  5   Adj Close  9632 non-null   float64
#  6   Volume     9632 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 526.9 KB

# %%
# cut a sample duration
df = df[df["Date"].dt.year>=2022]

# %%
sns.lineplot(data=df, x="Date", y="Open", alpha=.5, label="Open")
sns.lineplot(data=df, x="Date", y="High", alpha=.5, label="High")
sns.lineplot(data=df, x="Date", y="Low", alpha=.5, label="Low")
sns.lineplot(data=df, x="Date", y="Close", alpha=.5, label="Close")
sns.lineplot(data=df, x="Date", y="Adj Close", alpha=.5, label="Adj Close")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# One simple remark is that all the prices are very close to each other, so in this study, we will focus only on `"close"` value since it represents the price at the end of the day.

# %%
# checking influence of volume on close price
sns.scatterplot(data=df, x="Volume", y="Close")
plt.show()

# %% [markdown]
# The volume of transactions is mostly high when stock close price is too high, which reflects the behavior of investors in these regards (low shares of stocks when they are expensive).

# %%
# visualising the trends based on trading year
df["Year"] = df["Date"].dt.year

sns.scatterplot(data=df, x="Volume", y="Close", hue="Year")
plt.show()

# %% [markdown]
# This visualisation shows an interesting remark, the number of transactions got on a specific range apx: \[0.0, 2e8], which tells that the volume of trades lost its influence on the price (or the influence got inverted with the high stock price in recent years).
# in this case, probably the stock prices change with no other factor influencing it.

# %%
corr_tbl = df.corr()
corr_tbl.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_8d203_row0_col0, #T_8d203_row1_col1, #T_8d203_row1_col2, #T_8d203_row1_col3, #T_8d203_row1_col4, #T_8d203_row1_col5, #T_8d203_row2_col1, #T_8d203_row2_col2, #T_8d203_row2_col3, #T_8d203_row2_col4, #T_8d203_row2_col5, #T_8d203_row3_col1, #T_8d203_row3_col2, #T_8d203_row3_col3, #T_8d203_row3_col4, #T_8d203_row3_col5, #T_8d203_row4_col1, #T_8d203_row4_col2, #T_8d203_row4_col3, #T_8d203_row4_col4, #T_8d203_row4_col5, #T_8d203_row5_col1, #T_8d203_row5_col2, #T_8d203_row5_col3, #T_8d203_row5_col4, #T_8d203_row5_col5, #T_8d203_row6_col6, #T_8d203_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8d203_row0_col1 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_8d203_row0_col2 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_8d203_row0_col3 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_8d203_row0_col4 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_8d203_row0_col5, #T_8d203_row4_col0 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_8d203_row0_col6, #T_8d203_row6_col0, #T_8d203_row6_col1, #T_8d203_row6_col2, #T_8d203_row6_col3, #T_8d203_row6_col4, #T_8d203_row6_col5, #T_8d203_row6_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8d203_row0_col7 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_8d203_row1_col0, #T_8d203_row2_col0 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_8d203_row1_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_8d203_row1_col7, #T_8d203_row2_col7, #T_8d203_row7_col1, #T_8d203_row7_col4 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_8d203_row2_col6 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_8d203_row3_col0 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_8d203_row3_col6 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_8d203_row3_col7, #T_8d203_row4_col7, #T_8d203_row7_col3 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_8d203_row4_col6 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_8d203_row5_col0 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_8d203_row5_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_8d203_row5_col7, #T_8d203_row7_col5 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_8d203_row7_col0 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_8d203_row7_col2 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_8d203_row7_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8d203">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d203_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_8d203_level0_col1" class="col_heading level0 col1" >Open</th>
#       <th id="T_8d203_level0_col2" class="col_heading level0 col2" >High</th>
#       <th id="T_8d203_level0_col3" class="col_heading level0 col3" >Low</th>
#       <th id="T_8d203_level0_col4" class="col_heading level0 col4" >Close</th>
#       <th id="T_8d203_level0_col5" class="col_heading level0 col5" >Adj Close</th>
#       <th id="T_8d203_level0_col6" class="col_heading level0 col6" >Volume</th>
#       <th id="T_8d203_level0_col7" class="col_heading level0 col7" >Year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d203_level0_row0" class="row_heading level0 row0" >Date</th>
#       <td id="T_8d203_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8d203_row0_col1" class="data row0 col1" >0.775791</td>
#       <td id="T_8d203_row0_col2" class="data row0 col2" >0.774193</td>
#       <td id="T_8d203_row0_col3" class="data row0 col3" >0.782521</td>
#       <td id="T_8d203_row0_col4" class="data row0 col4" >0.778693</td>
#       <td id="T_8d203_row0_col5" class="data row0 col5" >0.791989</td>
#       <td id="T_8d203_row0_col6" class="data row0 col6" >-0.393923</td>
#       <td id="T_8d203_row0_col7" class="data row0 col7" >0.919489</td>
#     </tr>
#     <tr>
#       <th id="T_8d203_level0_row1" class="row_heading level0 row1" >Open</th>
#       <td id="T_8d203_row1_col0" class="data row1 col0" >0.775791</td>
#       <td id="T_8d203_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_8d203_row1_col2" class="data row1 col2" >0.998959</td>
#       <td id="T_8d203_row1_col3" class="data row1 col3" >0.998805</td>
#       <td id="T_8d203_row1_col4" class="data row1 col4" >0.997087</td>
#       <td id="T_8d203_row1_col5" class="data row1 col5" >0.996836</td>
#       <td id="T_8d203_row1_col6" class="data row1 col6" >-0.295659</td>
#       <td id="T_8d203_row1_col7" class="data row1 col7" >0.813497</td>
#     </tr>
#     <tr>
#       <th id="T_8d203_level0_row2" class="row_heading level0 row2" >High</th>
#       <td id="T_8d203_row2_col0" class="data row2 col0" >0.774193</td>
#       <td id="T_8d203_row2_col1" class="data row2 col1" >0.998959</td>
#       <td id="T_8d203_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_8d203_row2_col3" class="data row2 col3" >0.998815</td>
#       <td id="T_8d203_row2_col4" class="data row2 col4" >0.998689</td>
#       <td id="T_8d203_row2_col5" class="data row2 col5" >0.998332</td>
#       <td id="T_8d203_row2_col6" class="data row2 col6" >-0.283651</td>
#       <td id="T_8d203_row2_col7" class="data row2 col7" >0.813061</td>
#     </tr>
#     <tr>
#       <th id="T_8d203_level0_row3" class="row_heading level0 row3" >Low</th>
#       <td id="T_8d203_row3_col0" class="data row3 col0" >0.782521</td>
#       <td id="T_8d203_row3_col1" class="data row3 col1" >0.998805</td>
#       <td id="T_8d203_row3_col2" class="data row3 col2" >0.998815</td>
#       <td id="T_8d203_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_8d203_row3_col4" class="data row3 col4" >0.998880</td>
#       <td id="T_8d203_row3_col5" class="data row3 col5" >0.998804</td>
#       <td id="T_8d203_row3_col6" class="data row3 col6" >-0.311722</td>
#       <td id="T_8d203_row3_col7" class="data row3 col7" >0.818106</td>
#     </tr>
#     <tr>
#       <th id="T_8d203_level0_row4" class="row_heading level0 row4" >Close</th>
#       <td id="T_8d203_row4_col0" class="data row4 col0" >0.778693</td>
#       <td id="T_8d203_row4_col1" class="data row4 col1" >0.997087</td>
#       <td id="T_8d203_row4_col2" class="data row4 col2" >0.998689</td>
#       <td id="T_8d203_row4_col3" class="data row4 col3" >0.998880</td>
#       <td id="T_8d203_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_8d203_row4_col5" class="data row4 col5" >0.999760</td>
#       <td id="T_8d203_row4_col6" class="data row4 col6" >-0.299279</td>
#       <td id="T_8d203_row4_col7" class="data row4 col7" >0.815634</td>
#     </tr>
#     <tr>
#       <th id="T_8d203_level0_row5" class="row_heading level0 row5" >Adj Close</th>
#       <td id="T_8d203_row5_col0" class="data row5 col0" >0.791989</td>
#       <td id="T_8d203_row5_col1" class="data row5 col1" >0.996836</td>
#       <td id="T_8d203_row5_col2" class="data row5 col2" >0.998332</td>
#       <td id="T_8d203_row5_col3" class="data row5 col3" >0.998804</td>
#       <td id="T_8d203_row5_col4" class="data row5 col4" >0.999760</td>
#       <td id="T_8d203_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_8d203_row5_col6" class="data row5 col6" >-0.305154</td>
#       <td id="T_8d203_row5_col7" class="data row5 col7" >0.825127</td>
#     </tr>
#     <tr>
#       <th id="T_8d203_level0_row6" class="row_heading level0 row6" >Volume</th>
#       <td id="T_8d203_row6_col0" class="data row6 col0" >-0.393923</td>
#       <td id="T_8d203_row6_col1" class="data row6 col1" >-0.295659</td>
#       <td id="T_8d203_row6_col2" class="data row6 col2" >-0.283651</td>
#       <td id="T_8d203_row6_col3" class="data row6 col3" >-0.311722</td>
#       <td id="T_8d203_row6_col4" class="data row6 col4" >-0.299279</td>
#       <td id="T_8d203_row6_col5" class="data row6 col5" >-0.305154</td>
#       <td id="T_8d203_row6_col6" class="data row6 col6" >1.000000</td>
#       <td id="T_8d203_row6_col7" class="data row6 col7" >-0.315018</td>
#     </tr>
#     <tr>
#       <th id="T_8d203_level0_row7" class="row_heading level0 row7" >Year</th>
#       <td id="T_8d203_row7_col0" class="data row7 col0" >0.919489</td>
#       <t

# %% [markdown]
# This visualisation reveals that there is a weak correlation between volume and stock close price, but the date and the year has an even stronger one (the strongest).
# so we can only treat stock (close) prices with no intervention of other factors.

# %%
# analysing sequence influence
df = df[["Date", "Close"]]
def create_sequences(df: pd.DataFrame, n: int, colname: str, no_nan:bool=False):
    ret = df
    colnames = [colname]
    if n <= 1:
        raise ValueError("enter only values greater than 1")
    ret[colname+"_1"] = ret[colname].shift(1)
    colnames.append(colname+"_1")
    for i in range(1, n-1):
        ret[colname+"_"+str(i+1)] = ret[colname+"_"+str(i)].shift(1)
        colnames.append(colname+"_"+str(i+1))
    return (ret.iloc[n-1:] if no_nan else ret), colnames

# %% [markdown]
# # Predictions:
# In the prediction section, we will use **LSTM (Long short term memory) models**, which are Recurrent neural networks that can generate results based on the input data and past results (which are saved in a "memory").

# %%
# importing libraries
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.metrics import MeanAbsoluteError, MeanSquaredError, MeanAbsolutePercentageError, RootMeanSquaredError
from sklearn.preprocessing import MinMaxScaler

# Preparing data
per = .8
test_per = .1
sequence_length = 5

scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(df["Close"].values.reshape(-1, 1))

df["Close_scaled"] = scaler.transform(df[["Close"]])
vals, closes = create_sequences(df, sequence_length, "Close_scaled", True)
#vals, closes = create_sequences(df, sequence_length, "Close", True)
s1 = int(vals.shape[0] * per)
s2 = int(vals.shape[0] * per) + int(vals.shape[0] * test_per)

dates = vals["Date"]
d_train = dates.iloc[:s1].values
d_val = dates.iloc[s1:s2].values
d_test = dates.iloc[s2:].values
vals = vals.drop(["Date", "Close"], axis=1)

X = vals.drop("Close_scaled", axis=1)
y = vals["Close_scaled"]
X_train = X[:s1].values
X_test = X[s2:].values
y_train = y[:s1].values
y_test = y[s2:].values
X_val = X[s1:s2].values
y_val = y[s1:s2].values

X_train = np.reshape(X_train, (X_train.shape[0], -1, 1))
y_train = np.reshape(y_train, (y_train.shape[0], -1, 1))
X_test = np.reshape(X_test, (X_test.shape[0], -1, 1))
y_test = np.reshape(y_test, (y_test.shape[0], -1, 1))
X_val = np.reshape(X_val, (X_val.shape[0], -1, 1))
y_val = np.reshape(y_val, (y_val.shape[0], -1, 1))

# convert dates into numbers
X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape, d_train.shape, d_test.shape, d_val.shape
# Out:
# 2024-07-20 13:46:51.009587: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-20 13:46:51.040178: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-20 13:46:51.130213: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-20 13:46:51.305716: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-20 13:46:51.354047: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-20 13:46:51.471826: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-20 13:47:00.705080: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/mohammed/.local/lib/python3.10/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# ((481, 4, 1),
#  (481, 1, 1),
#  (61, 4, 1),
#  (61, 1, 1),
#  (60, 4, 1),
#  (60, 1, 1),
#  (481,),
#  (61,),
#  (60,))

# %%
# initialising neural network
nn = Sequential()

exp = 3
layer_length = 60
# adding layers
for _ in range(exp):
  nn.add(LSTM(layer_length, return_sequences=True))
  nn.add(Dropout(.2))

nn.add(LSTM(layer_length))
nn.add(Dropout(.2))
nn.add(Dense(1, activation="linear"))

nn.compile(optimizer='adam'
, loss='mean_squared_error'
, metrics=[MeanAbsoluteError(), MeanSquaredError(), MeanAbsolutePercentageError(), RootMeanSquaredError()])

# %%
# Train the model
nn.fit(X_train, y_train, epochs=21, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 41s 376ms/step - loss: 0.1249 - mean_absolute_error: 0.3019 - mean_absolute_percentage_error: 129576.0469 - mean_squared_error: 0.1249 - root_mean_squared_error: 0.3513 - val_loss: 0.0909 - val_mean_absolute_error: 0.2952 - val_mean_absolute_percentage_error: 35.4018 - val_mean_squared_error: 0.0909 - val_root_mean_squared_error: 0.3015
# Epoch 2/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0318 - mean_absolute_error: 0.1486 - mean_absolute_percentage_error: 1331876.7500 - mean_squared_error: 0.0318 - root_mean_squared_error: 0.1781 - val_loss: 0.2157 - val_mean_absolute_error: 0.4598 - val_mean_absolute_percentage_error: 55.4946 - val_mean_squared_error: 0.2157 - val_root_mean_squared_error: 0.4644
# Epoch 3/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0255 - mean_absolute_error: 0.1315 - mean_absolute_percentage_error: 101222.6328 - mean_squared_error: 0.0255 - root_mean_squared_error: 0.1592 - val_loss: 0.0375 - val_mean_absolute_error: 0.1896 - val_mean_absolute_percentage_error: 22.7521 - val_mean_squared_error: 0.0375 - val_root_mean_squared_error: 0.1936
# Epoch 4/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.0095 - mean_absolute_error: 0.0807 - mean_absolute_percentage_error: 111671.4062 - mean_squared_error: 0.0095 - root_mean_squared_error: 0.0970 - val_loss: 0.0021 - val_mean_absolute_error: 0.0374 - val_mean_absolute_percentage_error: 4.4363 - val_mean_squared_error: 0.0021 - val_root_mean_squared_error: 0.0462
# Epoch 5/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0032 - mean_absolute_error: 0.0453 - mean_absolute_percentage_error: 49324.7070 - mean_squared_error: 0.0032 - root_mean_squared_error: 0.0565 - val_loss: 0.0447 - val_mean_absolute_error: 0.2026 - val_mean_absolute_percentage_error: 24.2053 - val_mean_squared_error: 0.0447 - val_root_mean_squared_error: 0.2115
# Epoch 6/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.0039 - mean_absolute_error: 0.0454 - mean_absolute_percentage_error: 38567.3359 - mean_squared_error: 0.0039 - root_mean_squared_error: 0.0625 - val_loss: 0.0083 - val_mean_absolute_error: 0.0858 - val_mean_absolute_percentage_error: 10.2947 - val_mean_squared_error: 0.0083 - val_root_mean_squared_error: 0.0913
# Epoch 7/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.0034 - mean_absolute_error: 0.0459 - mean_absolute_percentage_error: 68435.5391 - mean_squared_error: 0.0034 - root_mean_squared_error: 0.0581 - val_loss: 0.0027 - val_mean_absolute_error: 0.0440 - val_mean_absolute_percentage_error: 5.2454 - val_mean_squared_error: 0.0027 - val_root_mean_squared_error: 0.0515
# Epoch 8/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.0029 - mean_absolute_error: 0.0409 - mean_absolute_percentage_error: 128611.4922 - mean_squared_error: 0.0029 - root_mean_squared_error: 0.0539 - val_loss: 0.0029 - val_mean_absolute_error: 0.0466 - val_mean_absolute_percentage_error: 5.5761 - val_mean_squared_error: 0.0029 - val_root_mean_squared_error: 0.0537
# Epoch 9/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - loss: 0.0021 - mean_absolute_error: 0.0350 - mean_absolute_percentage_error: 185704.4531 - mean_squared_error: 0.0021 - root_mean_squared_error: 0.0463 - val_loss: 9.9018e-04 - val_mean_absolute_error: 0.0240 - val_mean_absolute_percentage_error: 2.8905 - val_mean_squared_error: 9.9018e-04 - val_root_mean_squared_error: 0.0315
# Epoch 10/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0019 - mean_absolute_error: 0.0340 - mean_absolute_percentage_error: 69901.8984 - mean_squared_error: 0.0019 - root_mean_squared_error: 0.0439 - val_loss: 0.0019 - val_mean_absolute_error: 0.0376 - val_mean_absolute_percentage_error: 4.5589 - val_mean_squared_error: 0.0019 - val_root_mean_squared_error: 0.0437
# Epoch 11/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0025 - mean_absolute_error: 0.0385 - mean_absolute_percentage_error: 110826.3594 - mean_squared_error: 0.0025 - root_mean_squared_error: 0.0502 - val_loss: 0.0016 - val_mean_absolute_error: 0.0330 - val_mean_absolute_percentage_error: 4.0118 - val_mean_squared_error: 0.0016 - val_root_mean_squared_error: 0.0395
# Epoch 12/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0024 - mean_absolute_error: 0.0361 - mean_absolute_percentage_error: 148383.8750 - mean_squared_error: 0.0024 - root_mean_squared_error: 0.0490 - val_loss: 4.4911e-04 - val_mean_absolute_error: 0.0162 - val_mean_absolute_percentage_error: 1.9586 - val_mean_squared_error: 4.4911e-04 - val_root_mean_squared_error: 0.0212
# Epoch 13/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.0022 - mean_absolute_error: 0.0355 - mean_absolute_percentage_error: 247343.5469 - mean_squared_error: 0.0022 - root_mean_squared_error: 0.0466 - val_loss: 0.0012 - val_mean_absolute_error: 0.0292 - val_mean_absolute_percentage_error: 3.5973 - val_mean_squared_error: 0.0012 - val_root_mean_squared_error: 0.0349
# Epoch 14/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.0019 - mean_absolute_error: 0.0346 - mean_absolute_percentage_error: 10891.7910 - mean_squared_error: 0.0019 - root_mean_squared_error: 0.0434 - val_loss: 0.0023 - val_mean_absolute_error: 0.0434 - val_mean_absolute_percentage_error: 5.2094 - val_mean_squared_error: 0.0023 - val_root_mean_squared_error: 0.0476
# Epoch 15/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - loss: 0.0020 - mean_absolute_error: 0.0347 - mean_absolute_percentage_error: 66243.8750 - mean_squared_error: 0.0020 - root_mean_squared_error: 0.0448 - val_loss: 0.0013 - val_mean_absolute_error: 0.0322 - val_mean_absolute_percentage_error: 3.8379 - val_mean_squared_error: 0.0013 - val_root_mean_squared_error: 0.0362
# Epoch 16/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.0019 - mean_absolute_error: 0.0338 - mean_absolute_percentage_error: 165590.2656 - mean_squared_error: 0.0019 - root_mean_squared_error: 0.0441 - val_loss: 0.0026 - val_mean_absolute_error: 0.0461 - val_mean_absolute_percentage_error: 5.4917 - val_mean_squared_error: 0.0026 - val_root_mean_squared_error: 0.0507
# Epoch 17/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0019 - mean_absolute_error: 0.0325 - mean_absolute_percentage_error: 28290.8848 - mean_squared_error: 0.0019 - root_mean_squared_error: 0.0428 - val_loss: 0.0011 - val_mean_absolute_error: 0.0283 - val_mean_absolute_percentage_error: 3.3475 - val_mean_squared_error: 0.0011 - val_root_mean_squared_error: 0.0330
# Epoch 18/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.0017 - mean_absolute_error: 0.0339 - mean_absolute_percentage_error: 47800.9414 - mean_squared_error: 0.0017 - root_mean_squared_error: 0.0418 - val_loss: 5.0206e-04 - val_mean_absolute_error: 0.0177 - val_mean_absolute_percentage_error: 2.1824 - val_mean_squared_error: 5.0206e-04 - val_root_mean_squared_error: 0.0224
# Epoch 19/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.0026 - mean_absolute_error: 0.0404 - mean_absolute_percentage_error: 47288.4531 - mean_squared_error: 0.0026 - root_mean_squared_error: 0.0505 - val_loss: 9.8619e-04 - val_mean_absolute_error: 0.0266 - val_mean_absolute_percentage_error: 3.1259 - val_mean_squared_error: 9.8619e-04 - val_root_mean_squared_error: 0.0314
# Epoch 20/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0020 - mean_absolute_error: 0.0345 - mean_absolute_percentage_error: 56012.2773 - mean_squared_error: 0.0020 - root_mean_squared_error: 0.0450 - val_loss: 0.0020 - val_mean_absolute_error: 0.0405 - val_mean_absolute_percentage_error: 4.8362 - val_mean_squared_error: 0.0020 - val_root_mean_squared_error: 0.0450
# Epoch 21/21
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.0024 - mean_absolute_error: 0.0400 - mean_absolute_percentage_error: 78669.1562 - mean_squared_error: 0.0024 - root_mean_squared_error: 0.0489 - val_loss: 9.2774e-04 - val_mean_absolute_error: 0.0257 - val_mean_absolute_percentage_error: 3.0306 - val_mean_squared_error: 9.2774e-04 - val_root_mean_squared_error: 0.0305

# %%
# prediction
y_pred = scaler.inverse_transform(nn.predict(X_train)).flatten()
y_val_pred = scaler.inverse_transform(nn.predict(X_val)).flatten()
y_test_pred = scaler.inverse_transform(nn.predict(X_test)).flatten()

plt.plot(df["Date"], df["Close"], label="Real", c="red")

plt.plot(d_train, y_pred,  label="Predicted", c="blue")
plt.plot(d_test, y_test_pred, c="blue")
plt.plot(d_val, y_val_pred, c="blue")

plt.legend()
plt.xticks(rotation=45)
plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 261ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
